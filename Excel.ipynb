# %%
import pandas as pd
data = pd.read_excel (r'C:\Users\u183609\Documents\Copy of SpE_Matrix_Skills_Tools1.xlsx', sheet_name = 'CMDM')
df = pd.DataFrame(data, columns= ['Department','Employee Name', 'Title','Level', 'Program Role','Hardware CM', 'Software CM','Release Management/DevOps/Continuous Integration', 'Tools', 'Data Management', 'Asset Mgmt', 'Leadership'])
print(df)
# Out:
#      Department Employee Name      Title  Level Program Role  \
# 0           NaN           NaN        NaN    NaN          NaN
# 1           NaN           NaN        NaN    NaN          NaN
# 2           4.0    Employee 1    Title 1    2.0       Role 1
# 3           3.0    Employee 2    Title 2    4.0       Role 2
# 4           4.0    Employee 3    Title 3    2.0       Role 3
# ..          ...           ...        ...    ...          ...
# 97          2.0   Employee 96   Title 96    1.0      Role 96
# 98          3.0   Employee 97   Title 97    7.0      Role 97
# 99          5.0   Employee 98   Title 98    1.0      Role 98
# 100         3.0   Employee 99   Title 99    4.0      Role 99
# 101         2.0  Employee 100  Title 100    6.0     Role 100
#
#                                        Hardware CM                Software CM  \
# 0                                              NaN                        NaN
# ...

# %%
df = pd.read_excel (r'C:\Users\u183609\Documents\Copy of SpE_Matrix_Skills_Tools1.xlsx', sheet_name = 'IPS Skills')
print(df)
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0    E = Expert:\nSubject Matter expert … Able to h...        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                        Employee Name      Title      Level
# ..                                                 ...        ...        ...
# 100                                        Employee 96   Title 96          5
# 101                                        Employee 97   Title 97          7
# 102                                        Employee 98   Title 98          6
# 103                                        Employee 99   Title 99          4
# 104                                       Employee 100  Title 100          3
#
# ...
